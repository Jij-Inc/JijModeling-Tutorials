# %% [markdown]
# # JijModeling 1.14.1 リリースノート

# %% [markdown]
# ## バグ修正

# %% [markdown]
# ### プレースホルダーの形状メタデータの保持
#
# プロトコルバッファでのシリアライゼーション時に、プレースホルダーの形状メタデータが適切に保持されるように修正しました。この修正により、モデルの保存と読み込み時にプレースホルダーの形状情報が失われることがなくなりました。
