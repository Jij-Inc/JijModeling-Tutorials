# %% [markdown]
# # JijModeling 1.14.1 Release Notes

# %% [markdown]
# ## Bug Fixes

# %% [markdown]
# ### Preserve Placeholder Shape Metadata
#
# Fixed an issue where placeholder shape metadata was not properly preserved during protobuf serialization. This fix ensures that placeholder shape information is retained when saving and loading models.
