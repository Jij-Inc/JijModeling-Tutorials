# %% [markdown]
# # JijModeling 1.14.2 Release Notes

# %% [markdown]
# ## Bugfixes

# %% [markdown]
# ### Fix correctness bug in constraint detection
#
# Fixed the serious correctness bug in constraint detection, which mistakenly detect $\sum_i x_i \geq 1$ as SOS1.
